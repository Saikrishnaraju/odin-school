# %% [markdown]
# **Capstone Project on Credit Card Approval Prediction**

# %% [markdown]
# **Introduction**

# %% [markdown]
# One of the most widely utilized financial instruments is the credit card. But for many people, getting a credit card can be challenging because of a number of variables, including employment status and income level. Machine learning models can be used to forecast credit card approval, which can speed up the application process and increase the approval rate. In order to increase the accuracy of credit card approval predictions, we will investigate the ways in which different factors impact credit card acceptance rates and employ predictive models.

# %% [markdown]
# **Attribute Descriptions**

# %% [markdown]
# Gender: This column indicates the gender of the individual, either male or female. It is a Categorical (binary).
#
# Car_Owner: This column indicates whether the individual owns a car or not, either Yes or No.It is a Categorical (binary).
#
# Propert_Owner: This column indicates whether the individual owns a property or not, either Yes or No.It is a Categorical (binary).
#
# Children: This column indicates the number of children the individual has.It is a Numerical(integer).
#
# Annual_income: This column contains the annual income of the individual.It is a Numerical (continuous).
#
# Type_Income: This column indicates the type of income the individual earns, such as salary or self-employed income.It is a Numerical (nominal).
#
# Education: This column indicates the level of education of the individual. It is a Categorical (ordinal).
#
# Marital_status: This column indicates the marital status of the individual, such as Single, Married, Divorced, etc. It is a Categorical (nominal).
#
# Housing_type: This column indicates the type of housing the individual lives in, such as a house or apartment. It is a Categorical (nominal).
#
# Birthday_count: This column contains the age of the individual.It is a Numerical(integer).
#
# Employed_days: This column indicates the number of days the individual has been employed.It is a Numerical(integer).
#
# Mobile_phone, Work_Phone, Phone, and Email_id: These columns contain contact information for the individual, such as mobile phone number, work phone number, home phone number, and email id.Mobile_phone, Work_Phone, Phone are Categorical (binary) and Email_id is Categorical (nominal).
#
# Type_Occupation: This column indicates the type of occupation of the individual, such as healthcare or education. It is a Categorical (nominal).
#
# Family_Members: This column indicates the number of family members the individual has.It is a Numeric (integer).
#
# Label: This column contains the label for credit card approval, either approved or not approved. It is a Categorical (binary).

# %% [markdown]
# **Questions to Answer**

# %% [markdown]
# # **1. Why is your proposal important in today’s world? How predicting a good client is worthy for a bank?**

# %% [markdown]
# **A)** Because credit cards are being used more and more as financial tools, the idea to anticipate credit card approval is extremely pertinent in the modern world. Many people now use credit cards as their primary mode of payment due to the increase in e-commerce and online transactions. As a result, banks must process credit card applications quickly and increase the approval rate. A bank needs to be able to predict a good customer in order to lower the risk of credit default and credit card account management expenses. Banks can assess a variety of parameters, including employment status and income level, using machine learning algorithms.Banks can provide credit cards to customers with lower risk profiles by making precise predictions, which can eventually increase revenue and boost consumer satisfaction.

# %% [markdown]
# # **2. How is it going to impact the banking sector?**

# %% [markdown]
# **A)** Machine learning-based credit card approval prediction has the potential to completely change the banking industry by enhancing consumer satisfaction, lowering risk, and boosting earnings.
#
# **Better customer experience:** Banks can provide quicker and more accurate credit card approvals by utilizing predictive algorithms, which can enhance the general consumer experience. Increased client happiness and loyalty may result from this.
#
# **Decreased risk of credit defaults:** Banks can more precisely anticipate a customer's propensity to miss credit card payments with the use of machine learning algorithms. Banks can provide credit cards with reduced interest rates to customers who fit their lower credit risk profiles. This lowers the danger of default and eventually boosts the bank's profitability.
#
# **Enhanced profitability**: Banks can raise their profitability by lowering the risk of credit defaults and enhancing the effectiveness of the underwriting procedure. This can enable banks to provide their customers with better terms and perks, increasing their market share and earnings.

# %% [markdown]
# # **3. If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any bank in India.**

# %% [markdown]
# **A)** The suggested approach can help Indian banks fill any knowledge or process gaps regarding credit card approval by increasing the efficiency, strengthening credit risk management tactics, and predicting credit card approval more accurately. But banks will need to make sure they have access to trustworthy and complete data sources if they want to take full advantage of our suggested approach.

# %% [markdown]
# Here I am using ML Approach to solve the problem.

# %%
#Importing necessarry libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# Load the datasets
credit_card_data = pd.read_csv('Credit_card.csv')
credit_label_data = pd.read_csv('Credit_card_label.csv')

# Merge the datasets based on the common key 'Ind_ID'
merged_data = pd.merge(credit_card_data, credit_label_data, on='Ind_ID', how='inner')

# Save the merged dataset to a new CSV file if needed
merged_data.to_csv('Merged_Credit_Data.csv', index=False)

# %%
df=merged_data.copy()

# %%
# Display the first few rows of the merged dataset to verify the merge
df.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
# renaming the column names
df = df.rename(columns={'Ind_ID':'Ind_id', 'GENDER': 'Gender', 'CHILDREN': 'Children', 'EDUCATION': 'Education', 'EMAIL_ID':'Email_id','Birthday_count': 'Age','Employed_days':'Employed_exp'})

# %%
df.head()
# Out:
#     Ind_id Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#        Age  Employed_exp  Mobile_phone  Work_Phone  Phone  Email_id  \
# ...

# %%
df.shape
# Out:
# (1548, 19)

# %%
df.columns
# Out:
# Index(['Ind_id', 'Gender', 'Car_Owner', 'Propert_Owner', 'Children',
#        'Annual_income', 'Type_Income', 'Education', 'Marital_status',
#        'Housing_type', 'Age', 'Employed_exp', 'Mobile_phone', 'Work_Phone',
#        'Phone', 'Email_id', 'Type_Occupation', 'Family_Members', 'label'],
#       dtype='object')

# %%
df.tail()
# Out:
#        Ind_id Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      Education  \
# 1543  Commercial associate               Higher education
# 1544  Commercial associate              Incomplete higher
# 1545               Working               Higher education
# 1546               Working  Secondary / secondary special
# 1547               Working               Higher education
#
#             Marital_status       Housing_type      Age  Employed_exp  \
# 1543               Married  House / apartment -11957.0         -2182
# ...

# %%
df.describe()
# Out:
#              Ind_id     Children  Annual_income           Age   Employed_exp  \
# count  1.548000e+03  1548.000000   1.525000e+03   1526.000000    1548.000000
# mean   5.078920e+06     0.412791   1.913993e+05 -16040.342071   59364.689922
# std    4.171759e+04     0.776691   1.132530e+05   4229.503202  137808.062701
# min    5.008827e+06     0.000000   3.375000e+04 -24946.000000  -14887.000000
# 25%    5.045070e+06     0.000000   1.215000e+05 -19553.000000   -3174.500000
# 50%    5.078842e+06     0.000000   1.665000e+05 -15661.500000   -1565.000000
# 75%    5.115673e+06     1.000000   2.250000e+05 -12417.000000    -431.750000
# max    5.150412e+06    14.000000   1.575000e+06  -7705.000000  365243.000000
#
#        Mobile_phone   Work_Phone        Phone     Email_id  Family_Members  \
# count        1548.0  1548.000000  1548.000000  1548.000000     1548.000000
# mean            1.0     0.208010     0.309432     0.092377        2.161499
# ...

# %%
# find out the null values
df.isnull().sum()
# Out:
# Ind_id               0
# Gender               7
# Car_Owner            0
# Propert_Owner        0
# Children             0
# Annual_income       23
# Type_Income          0
# Education            0
# Marital_status       0
# Housing_type         0
# Age                 22
# Employed_exp         0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# Email_id             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
df.isnull()
# Out:
#       Ind_id  Gender  Car_Owner  Propert_Owner  Children  Annual_income  \
# 0      False   False      False          False     False          False
# 1      False   False      False          False     False          False
# 2      False   False      False          False     False          False
# 3      False   False      False          False     False           True
# 4      False   False      False          False     False          False
# ...      ...     ...        ...            ...       ...            ...
# 1543   False   False      False          False     False           True
# 1544   False   False      False          False     False          False
# 1545   False   False      False          False     False          False
# 1546   False   False      False          False     False          False
# 1547   False   False      False          False     False          False
#
#       Type_Income  Education  Marital_status  Housing_type    Age  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_id           1548 non-null   int64
#  1   Gender           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   Children         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   Education        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Age              1526 non-null   float64
#  11  Employed_exp     1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  Email_id         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
import missingno as msno

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
# creating matrix plot to see the pattern in missing values
msno.matrix(df)
# Out:
# <Axes: >

# %%
sorted = df.sort_values('Annual_income') # sorting values based on Annual Income
msno.matrix(sorted)
# Out:
# <Axes: >

# %%
msno.heatmap(df) # creating heatmap on correaltion
# Out:
# <Axes: >

# %%
# Imputing the null values with mean values
df.fillna(df.mean(), inplace=True)

# %%
# finding the null values.
df.isnull().sum()
# Out:
# Ind_id               0
# Gender               7
# Car_Owner            0
# Propert_Owner        0
# Children             0
# Annual_income        0
# Type_Income          0
# Education            0
# Marital_status       0
# Housing_type         0
# Age                  0
# Employed_exp         0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# Email_id             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
# replace missing values
df['Type_Occupation'].fillna('other',inplace=True)

# %%
# Deleting the null values in the Gender column
df=df.dropna(subset=["Gender"])

# %%
df.head(6)
# Out:
#     Ind_id Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0   180000.00000
# 1  5009744      F         Y             N         0   315000.00000
# 2  5009746      F         Y             N         0   315000.00000
# 3  5009749      F         Y             N         0   191399.32623
# 4  5009752      F         Y             N         0   315000.00000
# 6  5009754      F         Y             N         0   315000.00000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
# ...

# %%
# count the rows and columns
df.shape
# Out:
# (1541, 19)

# %%
df.columns
# Out:
# Index(['Ind_id', 'Gender', 'Car_Owner', 'Propert_Owner', 'Children',
#        'Annual_income', 'Type_Income', 'Education', 'Marital_status',
#        'Housing_type', 'Age', 'Employed_exp', 'Mobile_phone', 'Work_Phone',
#        'Phone', 'Email_id', 'Type_Occupation', 'Family_Members', 'label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1541 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_id           1541 non-null   int64
#  1   Gender           1541 non-null   object
#  2   Car_Owner        1541 non-null   object
#  3   Propert_Owner    1541 non-null   object
#  4   Children         1541 non-null   int64
#  5   Annual_income    1541 non-null   float64
#  6   Type_Income      1541 non-null   object
#  7   Education        1541 non-null   object
#  8   Marital_status   1541 non-null   object
#  9   Housing_type     1541 non-null   object
#  10  Age              1541 non-null   float64
#  11  Employed_exp     1541 non-null   int64
#  12  Mobile_phone     1541 non-null   int64
#  13  Work_Phone       1541 non-null   int64
#  14  Phone            1541 non-null   int64
#  15  Email_id         1541 non-null   int64
#  16  Type_Occupation  1541 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Ind_id             0
# Gender             0
# Car_Owner          0
# Propert_Owner      0
# Children           0
# Annual_income      0
# Type_Income        0
# Education          0
# Marital_status     0
# Housing_type       0
# Age                0
# Employed_exp       0
# Mobile_phone       0
# Work_Phone         0
# Phone              0
# Email_id           0
# Type_Occupation    0
# Family_Members     0
# label              0
# dtype: int64

# %%
# converting the negative values to actual age
df['Age']=abs(round((df['Age']/-365),0))
# converting negative values to exprience of the employee
df['Employed_exp']=abs(round((df['Employed_exp']/-365),0))

# %%
# replacing the extreme values with zero.
df['Employed_exp'].replace(1001.0, 0,inplace=True)

# %%
df.head()
# Out:
#     Ind_id Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0   180000.00000
# 1  5009744      F         Y             N         0   315000.00000
# 2  5009746      F         Y             N         0   315000.00000
# 3  5009749      F         Y             N         0   191399.32623
# 4  5009752      F         Y             N         0   315000.00000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#     Age  Employed_exp  Mobile_phone  Work_Phone  Phone  Email_id  \
# ...

# %%
# count number of males and females
gender_count=df['Gender'].value_counts()
#creat barpolt using Matplotlib
plt.bar(gender_count.index,gender_count.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender')
plt.show()

# %%
# count number of car owner
car_owner_count=df['Car_Owner'].value_counts()
#creat barpolt using Matplotlib
plt.bar(car_owner_count.index,car_owner_count.values)
plt.xlabel('car_owner_count')
plt.ylabel('Count')
plt.title('Distribution of car_owner')
plt.show()

# %%
# count number of propert_owner
propert_owner_count=df['Propert_Owner'].value_counts()
#creat barpolt using Matplotlib
plt.bar(propert_owner_count.index,propert_owner_count.values)
plt.xlabel('propert_owner_count')
plt.ylabel('Count')
plt.title('Distribution of propert_owner')
plt.show()

# %%
# count number of children
children_count=df['Children'].value_counts()
#creat barpolt using Matplotlib
plt.bar(children_count.index,children_count.values)
plt.xlabel('children_count')
plt.ylabel('count')
plt.title('Distribution of children_count')
plt.show()

# %%
# histograph on Annual_income
plt.hist(df['Annual_income'], bins=10)
plt.xlabel('Annual_income')
plt.ylabel('count')
plt.title('Distribution of Annual_income')
plt.show()

# %%
# count number of Type_Income
Type_Income_count=df['Type_Income'].value_counts()
#creat barpolt using Matplotlib
plt.bar(Type_Income_count.index,Type_Income_count.values)
plt.xlabel('Type_Income')
plt.ylabel('count')
plt.title('Distribution of Type_Income')
plt.show()

# %%
# count number of Education
Education_count=df['Education'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Education_count.index,Education_count.values)
plt.xlabel('Education')
plt.ylabel('count')
plt.title('Distribution of Education')
plt.show()

# %%
# count number of Marital_status
Marital_status_count=df['Marital_status'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Marital_status_count.index,Marital_status_count.values)
plt.xlabel('Marital_status')
plt.ylabel('count')
plt.title('Distribution of Marital_status')
plt.show()

# %%
# count number of Marital_status
Marital_status_count=df['Marital_status'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Marital_status_count.index,Marital_status_count.values)
plt.xlabel('Marital_status')
plt.ylabel('count')
plt.title('Distribution of Marital_status')
plt.show()

# %%
# count number of Housing_type
Housing_type_count=df['Housing_type'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Housing_type_count.index,Housing_type_count.values)
plt.xlabel('Housing_type')
plt.ylabel('count')
plt.title('Distribution of Housing_type')
plt.show()

# %%
# count number of Birthday_count
Birthday_count=df['Age'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Birthday_count.index,Birthday_count.values)
plt.xlabel('Age')
plt.ylabel('count')
plt.title('Distribution of Age')
plt.show()

# %%
# count number of Employed_days
Employed_days_count=df['Employed_exp'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Employed_days_count.index,Employed_days_count.values)
plt.xlabel('Employed_exp')
plt.ylabel('count')
plt.title('Distribution of Employed_exp')
plt.show()

# %%
# count number of Mobile_phone
Mobile_phone_count=df['Mobile_phone'].value_counts()
#creat barpolt using Matplotlib
plt.bar(Mobile_phone_count.index,Mobile_phone_count.values)
plt.xlabel('Mobile_phone')
plt.ylabel('count')
plt.title('Distribution of Mobile_phone')
plt.show()

# %%
# count number of Work_Phone
Work_Phone_count=df['Work_Phone'].value_counts()
#creat barpolt using Matplotlib
plt.bar(Work_Phone_count.index,Work_Phone_count.values)
plt.xlabel('Work_Phone')
plt.ylabel('count')
plt.title('Distribution of Work_Phone')
plt.show()

# %%
# count number of Phone
Phone_count=df['Phone'].value_counts()
#creat barpolt using Matplotlib
plt.bar(Phone_count.index,Phone_count.values)
plt.xlabel('Phone')
plt.ylabel('count')
plt.title('Distribution of Phone')
plt.show()

# %%
# count number of Email_id
Email_id_count=df['Email_id'].value_counts()
#creat barpolt using Matplotlib
plt.bar(Email_id_count.index,Email_id_count.values)
plt.xlabel('Email_id')
plt.ylabel('count')
plt.title('Distribution of Email_id')
plt.show()

# %%
# count number of Type_Occupation
Type_Occupation_count=df['Type_Occupation'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(30,10))
plt.bar(Type_Occupation_count.index,Type_Occupation_count.values)
plt.xlabel('Type_Occupation')
plt.ylabel('count')
plt.title('Distribution of Type_Occupation')
plt.show()

# %%
# count number of Family_Members
Family_Members_count=df['Family_Members'].value_counts()
#creat barpolt using Matplotlib
plt.bar(Family_Members_count.index,Family_Members_count.values)
plt.xlabel('Family_Members')
plt.ylabel('count')
plt.title('Distribution of Family_Members')
plt.show()

# %%
# count number of label
label_count=df['label'].value_counts()
#creat barpolt using Matplotlib
plt.bar(label_count.index,label_count.values)
plt.xlabel('label')
plt.ylabel('count')
plt.title('Distribution of label')
plt.show()

# %%
df.to_csv("final_project.csv")

# %%
df.head(2)
# Out:
#     Ind_id Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
#
#     Age  Employed_exp  Mobile_phone  Work_Phone  Phone  Email_id  \
# 0  51.0           0.0             1           0      0         0
# 1  37.0           2.0             1           1      1         0
#
#   Type_Occupation  Family_Members  label
# 0           other               2      1
# 1           other               2      1

# %% [markdown]
# **Relation between categorical variables**

# %%
# Find out the correlation between variables using spearman rank correlation
df2 = df.corr(method='spearman')
df2
# Out:
#                   Ind_id  Children  Annual_income       Age  Employed_exp  \
# Ind_id          1.000000  0.026155      -0.011117 -0.023564      0.025145
# Children        0.026155  1.000000       0.064120 -0.336771      0.156326
# Annual_income  -0.011117  0.064120       1.000000 -0.106760      0.165777
# Age            -0.023564 -0.336771      -0.106760  1.000000     -0.195991
# Employed_exp    0.025145  0.156326       0.165777 -0.195991      1.000000
# Mobile_phone         NaN       NaN            NaN       NaN           NaN
# Work_Phone      0.088004  0.040402      -0.069633 -0.164662      0.159235
# Phone           0.007702  0.014571      -0.020205  0.036688      0.008315
# Email_id       -0.044812  0.055700       0.116949 -0.161943     -0.004001
# Family_Members  0.007507  0.814514       0.039158 -0.276376      0.182474
# label           0.016660 -0.014037      -0.000154  0.048210     -0.100412
#
#                 Mobile_phone  Work_Phone     Phone  Email_id  Family_Members  \
# ...

# %%
#Visualization of correlation using Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df2,annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(x ='Gender',y ="Annual_income",data=df)
plt.show()

# %%
sns.boxplot(x ='Gender',y ="Age",data=df)
plt.show()

# %%
sns.boxplot(x ='Gender',y ="Employed_exp",data=df)
plt.show()

# %%
sns.boxplot(x ='Annual_income',y ="Marital_status",data=df)
plt.show()

# %%
sns.boxplot(x ='Family_Members',y ="Annual_income",data=df)
plt.show()

# %%
sns.boxplot(x ='Annual_income',y ="Education",data=df)
plt.show()

# %%
sns.boxplot(x ='Annual_income',y ="Type_Occupation",data=df)
plt.show()

# %%
df.head()
# Out:
#     Ind_id Gender Car_Owner Propert_Owner  Children  Annual_income  \
# 0  5008827      M         Y             Y         0   180000.00000
# 1  5009744      F         Y             N         0   315000.00000
# 2  5009746      F         Y             N         0   315000.00000
# 3  5009749      F         Y             N         0   191399.32623
# 4  5009752      F         Y             N         0   315000.00000
#
#             Type_Income         Education Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#     Age  Employed_exp  Mobile_phone  Work_Phone  Phone  Email_id  \
# ...

# %%
# removing unused columns
df = df.drop(['Ind_id', 'Mobile_phone','Work_Phone','Phone','Email_id'], axis=1)

# %% [markdown]
# **Feature Engineering**

# %%
# converting non numeric to numeric for train and test data
#Importing Label Encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in df:
  if df[col].dtype=='object':
    df[col]=le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1541 entries, 0 to 1547
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           1541 non-null   int64
#  1   Car_Owner        1541 non-null   int64
#  2   Propert_Owner    1541 non-null   int64
#  3   Children         1541 non-null   int64
#  4   Annual_income    1541 non-null   float64
#  5   Type_Income      1541 non-null   int64
#  6   Education        1541 non-null   int64
#  7   Marital_status   1541 non-null   int64
#  8   Housing_type     1541 non-null   int64
#  9   Age              1541 non-null   float64
#  10  Employed_exp     1541 non-null   float64
#  11  Type_Occupation  1541 non-null   int64
#  12  Family_Members   1541 non-null   int64
#  13  label            1541 non-null   int64
# dtypes: float64(3), int64(11)
# memory usage: 180.6 KB

# %%
df.shape
# Out:
# (1541, 14)

# %% [markdown]
# **Model Building**

# %%
# feature scaling
from sklearn.model_selection import train_test_split
# spliting the data
x = df.iloc[:,0:-1]
y = df.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=40)

# %%
# count the number rows and columns for x_test
x_test.shape
# Out:
# (463, 13)

# %%
# count the number rows and columns for x_train
x_train.shape
# Out:
# (1078, 13)

# %%
# count the number rows for y_test
y_test.shape
# Out:
# (463,)

# %%
# count the number rows for y_train
y_train.shape
# Out:
# (1078,)

# %% [markdown]
# **Scaling**

# %%
# importing the MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
rescale_x_train = scaler.fit_transform(x_train)
rescale_x_test = scaler.fit_transform(x_test)
print(rescale_x_train.shape)
print(rescale_x_test.shape)
# Out:
# (1078, 13)
# (463, 13)

# %% [markdown]
# Applying ML algorithms to the pre-processed columns and find out, which of these algorithms is best suitable.

# %% [markdown]
# **Logistic Regression**

# %%
# importing the LogisticRegression
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression(random_state=0)
logreg.fit(rescale_x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
#Importing scikit-learn metrics module for accuracy calculation
from sklearn import metrics
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = logreg.predict(rescale_x_test)
print("logistic regression training set:",logreg.score(x_train, y_train))
print("logistic regression testing set:",logreg.score(x_test, y_test))
print("Accuracy of logistic regression classifier: ", accuracy_score(y_test,y_pred))

print(confusion_matrix(y_test,y_pred))
# Out:
# logistic regression training set: 0.10946196660482375
# logistic regression testing set: 0.11231101511879049
# Accuracy of logistic regression classifier:  0.8876889848812095
# [[411   0]
#  [ 52   0]]

# %% [markdown]
# cross validation

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model= LogisticRegression()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.90291262 0.85436893 0.88673139 0.88996764 0.85760518 0.89320388
#  0.89967638 0.87702265 0.88996764 0.87055016]
# 0.882200647249191

# %% [markdown]
# **Decision Tree**

# %%
# decision tree classification  without rescaled
from sklearn.tree import DecisionTreeClassifier
classification = DecisionTreeClassifier()
classification = classification.fit(x_train,y_train)
y_pred = classification.predict(x_test)
print("decision tree training set:",classification.score(x_train, y_train))
print("decision tree testing set:",classification.score(x_test, y_test))
print("Accuracy:", accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# decision tree training set: 0.9944341372912802
# decision tree testing set: 0.8552915766738661
# Accuracy: 0.8552915766738661
# [[372  39]
#  [ 28  24]]

# %% [markdown]
# cross validation

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model= DecisionTreeClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.87378641 0.8381877  0.87702265 0.85436893 0.86084142 0.83495146
#  0.86731392 0.84789644 0.87378641 0.85760518]
# 0.8585760517799352

# %% [markdown]
# **XG boost**

# %%
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
xg=XGBClassifier()
xg=xg.fit(x_train,y_train)
y_pred=xg.predict(x_test)
print("xg training set:",xg.score(x_train, y_train))
print("xg testing set:",xg.score(x_test, y_test))
print("Accuracy:", accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# xg training set: 0.9935064935064936
# xg testing set: 0.9092872570194385
# Accuracy: 0.9092872570194385
# [[401  10]
#  [ 32  20]]

# %% [markdown]
# cross validation

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model=XGBClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.90291262 0.89320388 0.93203883 0.91585761 0.9223301  0.91262136
#  0.91909385 0.93203883 0.92880259 0.89967638]
# 0.9158576051779935

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)
print("rf training set:",rf.score(x_train, y_train))
print("rf testing set:",rf.score(x_test, y_test))
print("Random Forest classifier has accuracy of: ", rf.score(x_test, y_test))
# Evaluate the confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# rf training set: 0.9944341372912802
# rf testing set: 0.9222462203023758
# Random Forest classifier has accuracy of:  0.9222462203023758
# [[408   3]
#  [ 33  19]]

# %% [markdown]
# cross validation

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model=RandomForestClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.9223301  0.93203883 0.92556634 0.95145631 0.93203883 0.93527508
#  0.94822006 0.90938511 0.92880259 0.96116505]
# 0.9346278317152104

# %% [markdown]
# **Conclusion**

# %% [markdown]
# Thus, we obtained accuracy on several classifications.
#
# 1.logisitic regression achieved 88% accuracy.
#
#
# 2.DecisionTree achieved 85% accuracy.
#
# 3.xg boosting achieved 90% accuracy
#
# 4.Random Forest achieved 92% accuracy.
#
# We have completed all necessary basic EDA procedures and created a variety of graphs to show the correlation between the independent and dependent variables as well as between the independent variables.
#
# Following feature selection, we employed four machine learning models, and in Random Forest, we were able to predict credit card approval with an accuracy of 92%.

# %% [markdown]
# # **SQL Questions**

# %% [markdown]
# Loading cleaned data as cdf

# %%
cdf=pd.read_csv('final_project.csv')

# %%
import duckdb #importing neccesaary libraries for sql
conn=duckdb.connect()

# %%
conn.register("cdf",cdf) #registering cdf

# %%
conn.execute("select * from cdf").fetchdf()
# Out:
#       Unnamed: 0   Ind_id Gender Car_Owner Propert_Owner  Children  \
# 0              0  5008827      M         Y             Y         0
# 1              1  5009744      F         Y             N         0
# 2              2  5009746      F         Y             N         0
# 3              3  5009749      F         Y             N         0
# 4              4  5009752      F         Y             N         0
# ...          ...      ...    ...       ...           ...       ...
# 1536        1543  5028645      F         N             Y         0
# 1537        1544  5023655      F         N             N         0
# 1538        1545  5115992      M         Y             Y         2
# 1539        1546  5118219      M         Y             N         0
# 1540        1547  5053790      F         Y             Y         0
#
#       Annual_income           Type_Income                      Education  \
# 0      180000.00000             Pensioner               Higher education
# ...

# %%
# !pip install pymysql

# %%
# !pip install -q pandasql

import pandasql as psql

# %% [markdown]
# **1. Group the customers based on their income type and find the average of their annual income.**

# %%
conn.execute("select Type_Income , avg(Annual_income) as Average_Annual_Income from cdf group by Type_Income").fetchdf()
# Out:
#             Type_Income  Average_Annual_Income
# 0             Pensioner          155093.624738
# 1               Working          180375.175583
# 2         State servant          210130.434783
# 3  Commercial associate          233676.908269

# %% [markdown]
# **2. Find the female owners of cars and property.**

# %%
conn.execute("select * from cdf where Gender = 'F' and Car_Owner = 'Y' and Propert_Owner = 'Y';").fetchdf()
# Out:
#      Unnamed: 0   Ind_id Gender Car_Owner Propert_Owner  Children  \
# 0            11  5018498      F         Y             Y         0
# 1            12  5018501      F         Y             Y         0
# 2            13  5018503      F         Y             Y         0
# 3            25  5024213      F         Y             Y         0
# 4            37  5036660      F         Y             Y         0
# ..          ...      ...    ...       ...           ...       ...
# 172        1524  5048458      F         Y             Y         1
# 173        1525  5023719      F         Y             Y         0
# 174        1528  5033520      F         Y             Y         3
# 175        1540  5024049      F         Y             Y         1
# 176        1547  5053790      F         Y             Y         0
#
#      Annual_income           Type_Income                      Education  \
# 0      90000.00000               Working  Secondary / secondary special
# ...

# %% [markdown]
# **3. Find the male customers who are staying with their families.**

# %%
conn.execute("select * from cdf where Gender = 'M' and Family_Members >= '2';").fetchdf()
# Out:
#      Unnamed: 0   Ind_id Gender Car_Owner Propert_Owner  Children  \
# 0             0  5008827      M         Y             Y         0
# 1             8  5010864      M         Y             Y         1
# 2             9  5010868      M         Y             Y         1
# 3            14  5021303      M         N             N         1
# 4            15  5021310      M         N             Y         0
# ..          ...      ...    ...       ...           ...       ...
# 465        1534  5096856      M         Y             Y         0
# 466        1537  5090942      M         N             N         0
# 467        1542  5118268      M         Y             N         1
# 468        1545  5115992      M         Y             Y         2
# 469        1546  5118219      M         Y             N         0
#
#      Annual_income           Type_Income                      Education  \
# 0         180000.0             Pensioner               Higher education
# ...

# %% [markdown]
# Since family contains minimum 2 members so if there are equal or more than 2 members in family then considered as staying with thier family because we can't guess with children or housing type from data.

# %% [markdown]
# **4. Please list the top five people having the highest income.**

# %%
conn.execute("select * from cdf order by Annual_income desc limit 5").fetchdf()
# Out:
#    Unnamed: 0   Ind_id Gender Car_Owner Propert_Owner  Children  \
# 0         211  5143231      F         Y             Y         1
# 1         233  5143235      F         Y             Y         1
# 2         242  5090470      M         N             Y         1
# 3         686  5079016      M         Y             Y         2
# 4         811  5079017      M         Y             Y         2
#
#    Annual_income           Type_Income                      Education  \
# 0      1575000.0  Commercial associate               Higher education
# 1      1575000.0  Commercial associate               Higher education
# 2       900000.0               Working  Secondary / secondary special
# 3       900000.0  Commercial associate               Higher education
# 4       900000.0  Commercial associate               Higher education
#
#          Marital_status       Housing_type   Age  Employed_exp  Mobile_phone  \
# 0  Single / not married  House / apartment  28.0           7.0             1
# ...

# %% [markdown]
# Filtering the top five people from annual income with descending order by limit 5 gives us the list.

# %% [markdown]
# **5. How many married people are having bad credit?**

# %%
conn.execute("select count(*) from cdf where Marital_status = 'Married'or Marital_status ='Civil marriage' and label = 1;").fetchdf()
# Out:
#    count_star()
# 0          1048

# %% [markdown]
# Since married and civil marriage is also considered as marriage, so here i considered the both status.

# %% [markdown]
# **6. What is the highest education level and what is the total count?**

# %%
conn.execute("select count(*) as Total_Count from cdf where Education = 'Higher education';").fetchdf()
# Out:
#    Total_Count
# 0          421

# %% [markdown]
# Since Higher education is the highest education in data provided, i filtered by Higer education.

# %% [markdown]
# **7. Between married males and females, who is having more bad credit?**

# %%
conn.execute("select Gender, count(*) as Bad_Credit_Count from cdf where Marital_status = 'Married'or Marital_status ='Civil marriage' and label = 1 group by Gender;").fetchdf()
# Out:
#   Gender  Bad_Credit_Count
# 0      M               422
# 1      F               626

# %% [markdown]
# Since Label = 1 is application rejected so, females are having 626 higher number of rejections, so females are having bad credit.
